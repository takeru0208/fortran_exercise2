# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.loadtxt('ex3_for_python.dat')

plt.ylabel("num_student")
plt.xlabel("score")
plt.title("subject0")
plt.hist(data[::,0])
plt.show()

plt.ylabel("num_student")
plt.xlabel("score")
plt.title("subject1")
plt.hist(data[::,1])
plt.show()

plt.ylabel("num_student")
plt.xlabel("score")
plt.title("subject2")
plt.hist(data[::,2])
plt.show()

plt.ylabel("num_student")
plt.xlabel("score")
plt.title("subject3")
plt.hist(data[::,3])
plt.show()

plt.ylabel("num_student")
plt.xlabel("score")
plt.title("subject4")
plt.hist(data[::,4])
plt.show()

plt.ylabel("num_student")
plt.xlabel("score")
plt.title("subject5")
plt.hist(data[::,5])
plt.show()
